# %%
#!apt-get install texlive texlive-xetex texlive-latex-extra pandoc
#!pip install pypandoc

from google.colab import drive
#drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/My Drive/Colab Notebooks')
 
filenames = os.listdir('.')

print(filenames)
print(os.listdir('./html_files'))

# !ls
# !ls html_files
# Out:
# ['fred.txt', 'html_files', 'que.csv', 'File_Reading.ipynb', 'nani.csv', 'BinTreeAssignment.ipynb', 'Convert_Stuff.ipynb']
# ['BinTreeAssignment.html', 'Convert_Stuff.html', 'File_Reading.html']
# BinTreeAssignment.ipynb  File_Reading.ipynb  html_files  que.csv
# Convert_Stuff.ipynb	 fred.txt	     nani.csv
# BinTreeAssignment.html	Convert_Stuff.html  File_Reading.html

# %%
os.remove("html_files/File_Reading.html")

#!jupyter nbconvert --help
# !ls html_files 

# !jupyter nbconvert File_Reading.ipynb --to html --output-dir="html_files"

# fyi: this makes a new folder (once) and then puts your .html file there
# remove ' --output-dir="html_files" ' from the above if you don't want that


# !ls html_files
# Out:
# BinTreeAssignment.html	Convert_Stuff.html
# [NbConvertApp] Converting notebook File_Reading.ipynb to html
# [NbConvertApp] Writing 285136 bytes to html_files/File_Reading.html
# BinTreeAssignment.html	Convert_Stuff.html  File_Reading.html
